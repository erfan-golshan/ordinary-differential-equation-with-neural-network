# %%
import torch
from torch import nn

import matplotlib.pyplot as plt

import numpy as np

# %%
model = nn.Sequential(
    nn.Linear(1, 4),
    nn.Sigmoid(),
    nn.Linear(4, 1),
    ##############
)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(),lr=0.02,momentum=0.9)

# %% [markdown]
# ![Screenshot 2023-06-24 084420.jpg](data:image/jpeg;base64,...)

# %%
loss_list=[]

# dy/dx = 2x+1 , y(0) = 0

x = np.linspace(0,1,100)

for i in range(len(x)-1):
    y0 = model(torch.tensor([0.0]))
    xa = float(x[i])
    xb = float(x[i+1])
    ya = model(torch.tensor([xa]))
    yb = model(torch.tensor([xb]))

    dy = (yb-ya)/(xb-xa)

    loss1 = criterion(dy, torch.tensor([2*xb + 1]))
    loss2 = criterion(y0, torch.tensor([0.0]))
    loss = loss1 + loss2

    ####################
    loss_list.append(loss.item())
    ####################
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

plt.plot(loss_list)

# %%
x = np.linspace(0,1,100)
y=[]
for i in range(len(x)):
    y.append(model(torch.tensor([float(x[i])]))[0].item())


plt.rcParams["figure.figsize"] = [5, 4]
plt.rcParams["figure.autolayout"] = True
line1, = plt.plot(x , x**2+x , label="f")
line2, = plt.plot(x , y , label="nn")
leg = plt.legend(loc='upper center')
plt.show()

# %%
import random
loss_list=[]

# dy/dx = 2x+1 , y(0) = 0

x = np.linspace(0,1,100)

for _ in range(100):
    i = random.randint(1,98)
    y0 = model(torch.tensor([0.0]))
    xa = float(x[i])
    xb = float(x[i+1])
    ya = model(torch.tensor([xa]))
    yb = model(torch.tensor([xb]))

    dy = (yb-ya)/(xb-xa)

    loss1 = criterion(dy, torch.tensor([2*xb + 1]))
    loss2 = criterion(y0, torch.tensor([0.0]))
    loss = loss1 + loss2

    ####################
    loss_list.append(loss.item())
    ####################
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

plt.plot(loss_list)

# %%
x = np.linspace(0,1,100)
y=[]
for i in range(len(x)):
    y.append(model(torch.tensor([float(x[i])]))[0].item())


plt.rcParams["figure.figsize"] = [5, 4]
plt.rcParams["figure.autolayout"] = True
line1, = plt.plot(x , x**2+x , label="f")
line2, = plt.plot(x , y , label="nn")
#line3, = plt.plot(x , 2*x+1 , label="df/dx")
leg = plt.legend(loc='upper center')
plt.show()
